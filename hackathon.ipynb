# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
import pandas as pd

# %%
df_copy = pd.read_json("C:/Users/ASUS/Downloads/hackathon/messages.json")

# %%
df = df_copy

# %%
df_copy
# Out:
#                             userId        exportDate  \
# 0      8:live:.cid.4933a22bf564744  2022-06-11T00:06
# 1      8:live:.cid.4933a22bf564744  2022-06-11T00:06
# 2      8:live:.cid.4933a22bf564744  2022-06-11T00:06
# 3      8:live:.cid.4933a22bf564744  2022-06-11T00:06
# 4      8:live:.cid.4933a22bf564744  2022-06-11T00:06
# ...                            ...               ...
# 16284  8:live:.cid.4933a22bf564744  2022-06-11T00:06
# 16285  8:live:.cid.4933a22bf564744  2022-06-11T00:06
# 16286  8:live:.cid.4933a22bf564744  2022-06-11T00:06
# 16287  8:live:.cid.4933a22bf564744  2022-06-11T00:06
# 16288  8:live:.cid.4933a22bf564744  2022-06-11T00:06
#
#                                            conversations
# 0      {'id': '8:live:.cid.2ce9f8dccf1fc085', 'displa...
# 1      {'id': '8:live:.cid.78533d4cb35406cc', 'displa...
# 2      {'id': '8:live:.cid.a4c67d0b2e72bac6', 'displa...
# 3      {'id': '8:live:.cid.354621f1f9cfe2ea', 'displa...
# ...

# %%
print(df_copy['conversations'][566])
# Out:
# {'id': '19:898baf6f5680724aea0b3884b966963e92c72d6f2b52603c40ffd123c201df35@encrypted.skype', 'displayName': 'live:.cid.4933a22bf564744, live:.cid.2119caa810730412', 'version': 1654168231927.0, 'properties': {'conversationblocked': False, 'lastimreceivedtime': '2022-06-02T10:44:59.951Z', 'consumptionhorizon': '1649332120007;1652946922209;1649332120007', 'conversationstatus': None}, 'threadProperties': {'membercount': 2, 'members': '["8:live:.cid.4933a22bf564744","8:live:.cid.2119caa810730412"]', 'topic': 'live:.cid.4933a22bf564744, live:.cid.2119caa810730412', 'picture': None, 'description': None, 'guidelines': None}, 'MessageList': []}

# %%
dict = []
for i in range(len(df_copy['conversations'])):
    dict.append(df['conversations'][i]['MessageList'])

# %%
type(dict)
# Out:
# list

# %%
# len(dict)
# dict[0][len(dict[0])-1]['content']
# Out:
# '<ss type="hi">(wave)</ss>'

# %%
# dict = df['conversations'][1]['MessageList']
# len(dict)
# Out:
# 319

# %%
list_content = []
list_label = []
for j in range(len(dict)):
    if len(dict[j])!=0:
        list_content.append(dict[j][len(dict[j])-1]['content'])
        if dict[j][len(dict[j])-1]['displayName'] ==None:
            list_label.append(1)
        else:
            list_label.append(0)
        for i in range(len(dict[j])-2,-1,-1):
        #     if dict[i]['messagetype']=='RichText':
                if dict[j][i+1]['displayName']==dict[j][i]['displayName']:
                    list_content[-1] = list_content[-1] + ' ' + dict[j][i]['content']
                else:
                    list_content.append(dict[j][i]['content'])
                    if dict[j][i]['displayName'] ==None:
                        list_label.append(1)
                    else:
                        list_label.append(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5044/4077501877.py in <module>
#       3 for j in range(len(dict)):
#       4     if len(dict[j])!=0:
# ----> 5         list_content.append(dict[j][len(dict[j])-1]['content'])
#       6         if dict[j][len(dict[j])-1]['displayName'] ==None:
#       7             list_label.append(1)
#
# KeyboardInterrupt:

# %%
# list_content = []
# list_label = []
# list_content.append(dict[318]['content'])
# if dict[318]['displayName'] ==None:
#     list_label.append(1)
# else:
#     list_label.append(0)
# for i in range(len(dict)-2,-1,-1):
# #     if dict[i]['messagetype']=='RichText':
#         if dict[i+1]['displayName']==dict[i]['displayName']:
#             list_content[-1] = list_content[-1] + ' ' + dict[i]['content']
#         else:
#             list_content.append(dict[i]['content'])
#             if dict[i]['displayName'] ==None:
#                 list_label.append(1)
#             else:
#                 list_label.append(0)

# %%
df = pd.DataFrame({'lst1Tite' : list_label, 'lst2Tite' : list_content})

# %%
len(df['lst2Tite'])
# Out:
# 1034379

# %%
df.to_csv('whole_data_hackathon.csv')

# %%
df = pd.read_csv('data_hackathon2.csv')

# %%
# del df['Unnamed:0']
df
# Out:
#      lst1Tite                                           lst2Tite
# 0           0  Hello I have enrolled in the Machine Learning ...
# 1           1                         Kindly check your mail sir
# 2           0  I already checked it there is no mail for the ...
# 3           1  <a href="https://zoom.us/j/96193473094">https:...
# 4           0                                          Thank you
# ..        ...                                                ...
# 180         0  Is the degree compulsory for most of the compa...
# 181         1  I guess so at least a bachelor degree might be...
# 182         0  Ok sir. Sir is ineuron coming up with full sta...
# 183         1              Big Data Course will be launched soon
# 184         0                                                 ok
#
# [185 rows x 2 columns]

# %%
for i in range(len(df)):
    print(df.iloc[i])
# Out:
# lst1Tite                                                    0
# lst2Tite    Hello I have enrolled in the Machine Learning ...
# Name: 0, dtype: object
# lst1Tite                             1
# lst2Tite    Kindly check your mail sir
# Name: 1, dtype: object
# lst1Tite                                                    0
# lst2Tite    I already checked it there is no mail for the ...
# Name: 2, dtype: object
# lst1Tite                                                    1
# lst2Tite    <a href="https://zoom.us/j/96193473094">https:...
# Name: 3, dtype: object
# lst1Tite            0
# lst2Tite    Thank you
# Name: 4, dtype: object
# lst1Tite                      1
# lst2Tite    You&apos;re welcome
# Name: 5, dtype: object
# lst1Tite                                                    0
# lst2Tite    It is showing that The host has another meetin...
# Name: 6, dtype: object
# lst1Tite                        1
# lst2Tite    10 pm is the time sir
# Name: 7, dtype: object
# ...

# %%
df
# Out:
#          lst1Tite                                           lst2Tite
# 0               0                                       wave  hi sir
# 1               1                                           hi&apos;
# 2               0                                               sir
# 3               1                                             hello
# 4               0  i have completed the excel course where i need...
# ...           ...                                                ...
# 1034374         0  <partlist type="started" alt=""><part identity...
# 1034375         1  <addmember><eventtime>1587277641886</eventtime...
# 1034376         0  <ss type="hi">(wave)</ss> Hi \nFor any CNN mod...
# 1034377         1  The lenet has a specific architecture....but y...
# 1034378         0  <ss type="hi">(wave)</ss> testing the message....
#
# [1034379 rows x 2 columns]

# %%
import re    # regular expression
from nltk.corpus import stopwords

# set of stop words
stop = set(stopwords.words('english')) 

def remove_stop(word):
    if word not in stop:
        return word
    return ''
        
def lower_text(sentence):
    sentence=sentence.lower()
    return sentence

def cleanhtml(sentence):
    cleanr = re.compile('<.*?>')  # any thing in angular brackets
    cleantext = re.sub(cleanr, 'link', sentence) # replace with
    return cleantext

def cleanpunc(sentence):
    cleaned = re.sub(r'[?|!|\'|"|#]',r'', sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    return cleaned

# %%
for i in range(len(df['lst2Tite'])):
#     print(df['lst2Tite'].iloc[i])
    df['lst2Tite'].iloc[i] = lower_text(df['lst2Tite'].iloc[i])
    df['lst2Tite'].iloc[i] = cleanpunc(df['lst2Tite'].iloc[i])
    df['lst2Tite'].iloc[i] = cleanhtml(df['lst2Tite'].iloc[i])
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_5044/3859319637.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lst2Tite'].iloc[i] = lower_text(df['lst2Tite'].iloc[i])
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_5044/3859319637.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lst2Tite'].iloc[i] = cleanpunc(df['lst2Tite'].iloc[i])
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_5044/3859319637.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df

# %%
# for i in range(len(df['lst2Tite'])):
#     #print(df['lst2Tite'].iloc[i])
#     df['lst2Tite'].iloc[i] = lower_text(df['lst2Tite'].iloc[i])
#     df['lst2Tite'].iloc[i] = cleanpunc(df['lst2Tite'].iloc[i])
#     df['lst2Tite'].iloc[i] = cleanhtml(df['lst2Tite'].iloc[i])

# %%
# df

# %%
for i in range(len(df['lst2Tite'])):
     df['lst2Tite'].iloc[i] = ' '.join(list(map(remove_stop, df['lst2Tite'].iloc[i].split())))
# Out:
# C:\Users\ASUS\AppData\Local\Temp/ipykernel_5044/624434393.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['lst2Tite'].iloc[i] = ' '.join(list(map(remove_stop, df['lst2Tite'].iloc[i].split())))

# %%
df
# Out:
#      lst1Tite                                           lst2Tite
# 0           0  hello  enrolled machine learning  deep learnin...
# 1           1                              kindly check mail sir
# 2           0          already checked mail zoom link  send link
# 3           1                       https: zoom us j 96193473094
# 4           0                                              thank
# ..        ...                                                ...
# 180         0                degree compulsory company job roles
# 181         1   guess least bachelor degree might required ap...
# 182         0  ok sir sir ineuron coming full stack data engi...
# 183         1                      big data course launched soon
# 184         0                                                 ok
#
# [185 rows x 2 columns]

# %%
# answer_df = df[df['lst1Tite']==1]
# question_df = df[df['lst1Tite']==0]

# %%
question_df
answer_df
# Out:
#      lst1Tite                                           lst2Tite
# 1           1                         kindly check your mail sir
# 3           1              linkhttps:  zoom us j 96193473094link
# 5           1                                you&apos;re welcome
# 7           1                              10 pm is the time sir
# 9           1                                            yes sir
# ..        ...                                                ...
# 175         1                                                 ok
# 177         1                              tell me what you need
# 179         1  no not required for the screening process but ...
# 181         1  i guess so at least a bachelor degree might be...
# 183         1              big data course will be launched soon
#
# [92 rows x 2 columns]

# %%
question_df['lst2Tite'].to_list()
# Out:
# ['hello i have enrolled in the machine learning and deep learning masters course \n can i have the link of today&apos;s doubt clearing session',
#  'i already checked it there is no mail for the zoom link can you send the link',
#  'thank you',
#  'it is showing that the host has another meeting in progress',
#  'ok so i cant join now',
#  '    linkto view this shared photo  go to: linkhttps:  login skype com login ssogo=xmmfallbackpic=0-sa-d8-a0e46ab5c998a652e9ddd3b9fb8bd5dblinklinklinklinklinklinklinklink sir i am facing issue in this code  if you can help in this please guide',
#  'the last cell never stops running and i can&apos;t open the webapp ',
#  'yes i did that but it is not working',
#  'ok sir is doubt clearing session started or not',
#  '10th april ml batch',
#  'please wait for the host to start this webinar',
#  'zoom is showing this ok sorry',
#  'yes sir thank you again',
# ...

# %%
maxlen=1000
max_features=5000 
embed_size=300

#clean some null words or use the previously cleaned & lemmatized corpus
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
label_y= LabelEncoder()
train_y=label_y.fit_transform(answer_df['lst2Tite'])

train_x,test_x,train_y,test_y=train_test_split(question_df['lst2Tite'],train_y,test_size=0.2,random_state=42)

val_x = test_x
tokenizer=Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(train_x))
train_x=tokenizer.texts_to_sequences(train_x)
val_x=tokenizer.texts_to_sequences(val_x)

#Pad the sequence- To allow same length for all vectorized words
train_x=pad_sequences(train_x,maxlen=maxlen)
val_x=pad_sequences(val_x,maxlen=maxlen)
val_y=test_y
print("Padded and Tokenized Training Sequence".format(),train_x.shape)
print("Target Values Shape".format(),train_y.shape)
print("Padded and Tokenized Training Sequence".format(),val_x.shape)
print("Target Values Shape".format(),val_y.shape)

# %%
model=Sequential()
model.add(Embedding(max_features,embed_size,input_length=maxlen))
model.add(LSTM(60))
model.add(Dense(16,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
plot_model(
    model,
    to_file="simple_model.png",
    show_shapes=True,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
)
model.fit(train_x,train_y,batch_size=512,epochs=3,verbose=2)

# %%
from PIL import Image 
import matplotlib.pyplot as plt
im = Image.open("simple_model.png") 
im.show()
plt.show()

# %%
from keras.preprocessing.sequence import pad_sequences
from tensorflow import keras
from keras.preprocessing.text import Tokenizer
maxlen=1000
max_features=5000 
embed_size=300

train_sample=train_df['review']

#Tokenizing steps- must be remembered
tokenizer=Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(train_sample))
train_sample=tokenizer.texts_to_sequences(train_sample)

#Pad the sequence- To allow same length for all vectorized words
train_sample=pad_sequences(train_sample,maxlen=maxlen)



EMBEDDING_FILE = '../input/wikinews300d1msubwordvec/wiki-news-300d-1M-subword.vec'
def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE) if len(o)>100)

all_embs = np.stack(embeddings_index.values())
emb_mean,emb_std = all_embs.mean(), all_embs.std()
embed_size = all_embs.shape[1]

word_index = tokenizer.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector
plt.plot(embedding_matrix[20])
plt.show()

# %%
from keras.preprocessing.sequence import pad_sequences
from tensorflow import keras
from keras.preprocessing.text import Tokenizer
maxlen=1000
max_features=5000 
embed_size=300

train_sample=question_df['lst2Tite'][1:121:2]

#Tokenizing steps- must be remembered
tokenizer=Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(train_sample))
train_sample=tokenizer.texts_to_sequences(train_sample)

#Pad the sequence- To allow same length for all vectorized words
train_sample=pad_sequences(train_sample,maxlen=maxlen)



EMBEDDING_FILE = '../input/glove-global-vectors-for-word-representation/glove.6B.50d.txt'
def get_coefs(word,*arr): return word, np.asarray(arr, dtype='float32')
embeddings_index = dict(get_coefs(*o.split(" ")) for o in open(EMBEDDING_FILE) if len(o)>100)

all_embs = np.stack(embeddings_index.values())
emb_mean,emb_std = all_embs.mean(), all_embs.std()
embed_size = all_embs.shape[1]

word_index = tokenizer.word_index
nb_words = min(max_features, len(word_index))
embedding_matrix = np.random.normal(emb_mean, emb_std, (nb_words, embed_size))
for word, i in word_index.items():
    if i >= max_features: continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None: embedding_matrix[i] = embedding_vector

        
        inp=Input(shape=(maxlen,))
z=Embedding(max_features,embed_size,weights=[embedding_matrix])(inp)
z=Bidirectional(LSTM(60,return_sequences='True'))(z)
z=GlobalMaxPool1D()(z)
z=Dense(16,activation='relu')(z)
z=Dense(1,activation='softmax')(z)
model=Model(inputs=inp,outputs=z)
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
plot_model(
    model,
    to_file="glove_simple_model.png",
    show_shapes=True,
    show_layer_names=True,
    rankdir="TB",
    expand_nested=False,
    dpi=96,
)

model.fit(train_x,train_y,batch_size=128,epochs=3,verbose=2,validation_data=(val_x,val_y))
